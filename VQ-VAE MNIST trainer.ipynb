# %%
import torch
import torch.optim as optim
import torch.utils.data as data
import torchvision.datasets as datasets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
# %matplotlib inline

from neural import VQVAE

# %% [markdown]
# ## Data Loaders

# %%
BATCH_SIZE = 128
SHUFFLE = True
NUM_WORKERS = 12

# %%
train_set_loader = data.DataLoader(
    datasets.MNIST('./', train=True, transform=transforms.ToTensor(), download=True),
    batch_size=BATCH_SIZE,
    shuffle=SHUFFLE,
    num_workers=NUM_WORKERS,
)

test_set_loader = data.DataLoader(
    datasets.MNIST('./', train=False, transform=transforms.ToTensor(), download=True),
    batch_size=BATCH_SIZE,
    shuffle=SHUFFLE,
    num_workers=NUM_WORKERS,
)

# %% [markdown]
# ## Net and Optimizer

# %%
net = VQVAE(128, 8, 0.25)
optimizer = optim.Adam(net.parameters(), lr=1e-4)

# %%
try:
    net.load_state_dict(torch.load(open('state_dict.pth', 'rb')))
    print('State Dict loaded from \'state_dict.pth\'')
except:
    pass

# %% [markdown]
# ## Train Loop

# %%
def train(epochs=10):
    print('='*10, end='')
    print(' TRAIN', end=' ') 
    print('='*10, end='\n\n')
    net.train()

    for epoch in range(1, epochs+1):
        running_loss = 0

        for i, batch in enumerate(train_set_loader, 1):
            images, _ = batch
            
            # Zero grad
            optimizer.zero_grad()

            # Forward
            encoded, quantized, recon_x = net(images)
            # Compute Loss
            loss_value = net.loss_function(images, recon_x, encoded, quantized)
            running_loss += loss_value.item()
            # Backward
            loss_value.backward()
            # Update
            optimizer.step()

            if i % 100 == 0:
                print(f'==> EPOCH[{epoch}]({i}/{len(train_set_loader)}): LOSS: {loss_value.item()}')
            
        print(f'=====> EPOCH[{epoch}] Completed: Avg. LOSS: {running_loss/len(train_set_loader)}')
        print()

# %%
train(100)
# Out:
# ========== TRAIN ==========
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-51afd2885487> in <module>
# ----> 1 train(100)
#
# <ipython-input-6-c5da651a4053> in train(epochs)
#      20             running_loss += loss_value.item()
#      21             # Backward
# ---> 22             loss_value.backward()
#      23             # Update
#      24             optimizer.step()
#
# ~/.local/share/virtualenvs/qvae-rACEtkm2/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# ~/.local/share/virtualenvs/qvae-rACEtkm2/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
image, label = test_set_loader.dataset[10]

encoded, quantized, recon = net(image.unsqueeze(0))

recon = recon[0].squeeze()
plt.imshow(recon.detach().numpy(), cmap='Greys');

# %%
net.vq.embeddings.weight[0, :]

# %%
quantized.shape

# %%
encodings = torch.zeros(28*28, 128)
encodings[14, 12] = 1
encodings[32, 1] = 1
quantized = encodings @ net.vq.embeddings.weight

# %%
quantized = quantized.reshape((1, 28, 28, 8)).permute(0, 3, 1, 2)

# %%
recon = net.decoder(quantized)[0].squeeze()
plt.imshow(recon.detach().numpy(), cmap='Greys');

# %%
image, label = test_set_loader.dataset[20]
image = image.view(-1, 28*28).unsqueeze(0)

mu, sigma = net.encode(image)
z_2 = mu + sigma * torch.rand_like(sigma)

recon = net.decode(z_2)
print(label)
plt.imshow(recon.view(28, 28).detach().numpy(), cmap='Greys');

# %%
z_3 = z_2 - z_1
recon = net.decode(z_3)
plt.imshow(recon.view(28, 28).detach().numpy(), cmap='Greys');

# %%
torch.save(net.state_dict(), open('vqa_state_dict.pth', 'wb'))
